# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\bedox\Desktop\DATA SETS\Brats2021\Dice_scores.csv")
print(df.describe())
# Out:
#         Dice Score
# count  1251.000000
# mean      0.851011
# std       0.114681
# min       0.125757
# 25%       0.812064
# 50%       0.886353
# 75%       0.928243
# max       0.977999

# %%
df[df["Dice Score"] < 0.2]
# Out:
#          Patient  Dice Score
# 948   Case 01364    0.142728
# 1075  Case 01491    0.179106
# 1114  Case 01530    0.125757

# %%
sns.histplot(data=df, x="Dice Score", kde=True );
# plt.xticks(np.arange(0, 1.1, 0.1));

# %%
sns.boxplot(
    data=df, y="Dice Score",
    notch=True, showcaps=False,
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},
)
plt.yticks(np.arange(0, 1.1, 0.1));

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x258f9cb7b80>,
#   <matplotlib.lines.Line2D at 0x258f9cb7e20>],
#  'caps': [<matplotlib.lines.Line2D at 0x258f9cc6100>,
#   <matplotlib.lines.Line2D at 0x258f9cc63a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x258f9cb78e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x258f9cc6640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x258f9cc6910>],
#  'means': []}
