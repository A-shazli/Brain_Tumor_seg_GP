# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped.zip" -d "/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped"
# Out:
# Archive:  /content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped.zip
#    creating: /content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped/
#    creating: /content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/
#   inflating: /content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/BraTS2021_00000_flair.nii.gz
#   inflating: /content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/BraTS2021_00000_seg.nii.gz
#   inflating: /content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/BraTS2021_00000_t1.nii.gz
# ...

# %%
# !unzip "/content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped.zip" -d "/content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped"
# Out:
# Archive:  /content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped.zip
#    creating: /content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/T1 Synthesized BraTS Validation Brain Cropped/
#    creating: /content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/T1 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/
#   inflating: /content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/T1 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/BraTS2021_00000_flair.nii.gz
#   inflating: /content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/T1 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/BraTS2021_00000_seg.nii.gz
#   inflating: /content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/T1 Synthesized BraTS Validation Brain Cropped/BraTS2021_00000/BraTS2021_00000_t1.nii.gz
# ...

# %%
def black_seq_generator(test_path, brats_num, T1_FLAG=True, T2_FLAG=True, FLAIR_FLAG=True):
    test_data_list = sorted(glob.glob(test_path + '/*'))
    original_vol_path = sorted(glob.glob(test_path + '/*'))[0]
    original_vol = nib.load(original_vol_path)
    original_shape = original_vol.shape

    v = np.zeros(original_shape)
    v = nib.Nifti1Image(v, original_vol.affine)  # to save this 3D (ndarry) numpy

    if FLAIR_FLAG:
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_flair.nii.gz')
    if T1_FLAG:
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t1.nii.gz')
    if T2_FLAG:
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t2.nii.gz')

    if T1_FLAG and T2_FLAG:
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t1.nii.gz')
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t2.nii.gz')
    if T1_FLAG and FLAIR_FLAG:
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t1.nii.gz')
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_flair.nii.gz')
    if T2_FLAG and FLAIR_FLAG:
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_flair.nii.gz')
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t2.nii.gz')
    print("Done")

# %%
import shutil
import os

# %%
import shutil
import os

# Define the path to the parent directory
parent_dir = '/content/drive/MyDrive/GP/BraTS Validation Brain Cropped'

# Define the path to the new location where you want to copy the parent folder
new_location = '/content/drive/MyDrive/GP/Black T1c BraTS Validation Brain Cropped'


# Copy the parent folder to the new location
shutil.copytree(parent_dir, new_location)
# Out:
# '/content/drive/MyDrive/GP/Black T1c BraTS Validation Brain Cropped'

# %%
parent_dir = '/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped'
new_location = '/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/Black T2 BraTS Validation Brain Cropped'
shutil.copytree(parent_dir, new_location)
# Out:
# '/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/Black T2 BraTS Validation Brain Cropped'

# %%
import os
parent_dir = '/content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/Black T1 BraTS Validation Brain Cropped'
os.listdir(parent_dir)[0]
# Out:
# 'BraTS2021_00000'

# %%
import os
import nibabel as nib
import numpy as np

# Define the path to the parent directory
parent_dir = '/content/drive/MyDrive/GP/Black T1c BraTS Validation Brain Cropped'

# Loop over all subdirectories in the parent directory
for subdir in os.listdir(parent_dir):
    # Define the path to the subdirectory
    sub_dir_path = os.path.join(parent_dir, subdir)
    # Loop over all NIfTI files in the subdirectory
    for file in os.listdir(sub_dir_path):
        if file.endswith('t1ce.nii.gz'):
            # Define the path to the T1 file
            t1_path = os.path.join(sub_dir_path, file)
            # Load the T1 file
            t1 = nib.load(t1_path)
            # Get the dimensions of the T1 file
            dims = t1.shape
            # Create a black volume with the same dimensions as the T1 file
            black_vol = np.zeros(dims)
            # Define the path to save the black volume
            black_vol_path = os.path.join(sub_dir_path, file)
            # Save the black volume as a NIfTI file
            nib.save(nib.Nifti1Image(black_vol, t1.affine), black_vol_path)

# %%
import os
import nibabel as nib
import numpy as np

# Define the path to the parent directory
parent_dir = '/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/Black T2 BraTS Validation Brain Cropped'

# Loop over all subdirectories in the parent directory
for subdir in os.listdir(parent_dir):
    # Define the path to the subdirectory
    sub_dir_path = os.path.join(parent_dir, subdir)
    # Loop over all NIfTI files in the subdirectory
    for file in os.listdir(sub_dir_path):
        if file.endswith('t2.nii.gz'):
            # Define the path to the T1 file
            t1_path = os.path.join(sub_dir_path, file)
            # Load the T1 file
            t1 = nib.load(t1_path)
            # Get the dimensions of the T1 file
            dims = t1.shape
            # Create a black volume with the same dimensions as the T1 file
            black_vol = np.zeros(dims)
            # Define the path to save the black volume
            black_vol_path = os.path.join(sub_dir_path, file)
            # Save the black volume as a NIfTI file
            nib.save(nib.Nifti1Image(black_vol, t1.affine), black_vol_path)

# %%
path = '/content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/Black T1 BraTS Validation Brain Cropped/BraTS2021_00016/BraTS2021_00016_t1.nii.gz'
x = nib.load(path).get_fdata()
print(x.shape, x.max())
# Out:
# (135, 172, 138) 0.0

# %%
# Define the path to the parent directory
parent_dir = '/content/drive/MyDrive/GP/T1 Synthesized BraTS Validation Brain Cropped/T1 Synthesized BraTS Validation Brain Cropped'

# Define the path to the new location where you want to copy the parent folder
new_location = '/content/drive/MyDrive/GP/FLAIR Synthesized BraTS Validation Brain Cropped'


# Copy the parent folder to the new location
shutil.copytree(parent_dir, new_location)
# Out:
# '/content/drive/MyDrive/GP/FLAIR Synthesized BraTS Validation Brain Cropped'

# %%
import os
import shutil

# Define the paths to the source and destination folders
src_path = '/content/drive/MyDrive/GP/T2 Synthesized BraTS Validation Brain Cropped/T2 Synthesized BraTS Validation Brain Cropped'
dst_path = '/content/drive/MyDrive/GP/FLAIR Synthesized BraTS Validation Brain Cropped'

# Loop over all subfolders in the source folder
for subdir in os.listdir(src_path):
    subdir_path = os.path.join(src_path, subdir)
    if os.path.isdir(subdir_path):
        # Loop over all files in the subfolder
        for file_name in os.listdir(subdir_path):
            if file_name.endswith('t1.nii.gz'):
                # Construct the paths to the source and destination files
                src_file = os.path.join(subdir_path, file_name)
                dst_file = os.path.join(dst_path, subdir, file_name)

                # Copy the file to the destination folder, replacing any existing file
                shutil.copyfile(src_file, dst_file)

# %%
import os
import nibabel as nib
import numpy as np

# Define the path to the parent directory
parent_dir = '/content/drive/MyDrive/GP/FLAIR Synthesized BraTS Validation Brain Cropped'

# Loop over all subdirectories in the parent directory
for subdir in os.listdir(parent_dir):
    # Define the path to the subdirectory
    sub_dir_path = os.path.join(parent_dir, subdir)
    # Loop over all NIfTI files in the subdirectory
    for file in os.listdir(sub_dir_path):
        if file.endswith('flair.nii.gz'):
            # Define the path to the T1 file
            t1_path = os.path.join(sub_dir_path, file)
            # Load the T1 file
            t1 = nib.load(t1_path)
            # Get the dimensions of the T1 file
            dims = t1.shape
            # Create a black volume with the same dimensions as the T1 file
            black_vol = np.zeros(dims)
            # Define the path to save the black volume
            black_vol_path = os.path.join(sub_dir_path, file)
            # Save the black volume as a NIfTI file
            nib.save(nib.Nifti1Image(black_vol, t1.affine), black_vol_path)
