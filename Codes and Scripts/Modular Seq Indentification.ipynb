# %%
import sys
sys.path.append('C:\\Users\\DELL\\Graduation Project\\Codes and Scripts\\type-identification-mri-sequences\\')

import os
import random
import cv2
import time
import glob
import pandas as pd
import nibabel as nib
import numpy as np
import imageio
from scipy import ndimage
import shutil

import torch
import torch.utils.data as data
import tensorflow as tf

from models import select_net
from time_util import time_format
from MedicalDataset import MedicalDataset

from HelperFunctions import preprocess_image_train, generate_images_GIF, predict_image, black_seq_generator
from SynthModels import ResNet, unet_model, Discriminator, old_squeeze, SqueezeAttention, gans_SqueezeAttention
# Out:
# C:\Users\DELL\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
def fix_random_seeds():
    torch.backends.cudnn.deterministic = True
    random.seed(1)
    torch.manual_seed(1)
    torch.cuda.manual_seed(1)
    np.random.seed(1)

def csv_maker(path):
    
    #1- making the CSV
    test_path = path
    test_data_list = sorted(glob.glob(test_path + '/*'))

    #Delete segmentation(labels)
    for test_data in test_data_list:
        if test_data.endswith('seg.nii.gz'):
            os.remove(test_data)        
    test_data_list = sorted(glob.glob(test_path + '/*'))

    num_rows = len(test_data_list)
    test_data = pd.DataFrame({'path': test_data_list, 'label': np.nan})
    print(test_data)
    return test_path, test_data_list, num_rows, test_data
    
def seq_identification(path, model_file):
    test_path, test_data_list, num_rows, test_data = csv_maker(path)
    n_slices = 4
    tridim = False
    consider_other_class = not '--no-other'
    architecture = 'resnet18'

    assert(architecture in ['resnet18', 'alexnet', 'vgg', 'squeezenet', 'mobilenet'])

    fix_random_seeds()
    test_set = MedicalDataset(test_data, min_slices = n_slices, consider_other_class = consider_other_class, test = True)
    test_loader = data.DataLoader(test_set, num_workers = 8, pin_memory = True)

    n_test_files = test_set.__len__()
    classes = ['FLAIR', 'T1', 'T1c', 'T2']
    paths = []
    net = select_net(architecture, n_slices, tridim, consider_other_class)

    if torch.cuda.is_available():
        net = net.cuda()

    start_time = time.time()

    #test
    net.load_state_dict(torch.load(os.path.join('models', model_file), map_location=torch.device('cpu')))
    net.eval()
    correct = 0
    total = 0
    correct_per_class = [0] * len(classes)
    total_per_class = [0] * len(classes)
    actual_classes = []
    predicted_classes = []
    wrong_predictions = []
    flag = 0
    with torch.no_grad():
        for i, (pixel_data, label, path) in enumerate(test_loader):
            print('Tested', i + 1, 'of', n_test_files, 'files.')
            label_as_num = label.numpy()[0]
            if tridim:
                pixel_data = pixel_data.view(-1, 1, 10, 200, 200)

            outputs = net(pixel_data) #.cuda()
            _, predicted = torch.max(outputs.data, 1)

            predicted_classes.append(classes[predicted.cpu().numpy()[0]])
            paths.append(path[0])
            flag += 1
            if flag == 4:
    #             predicted_classes.clear()
    #             paths.clear()
                flag = 0


        if set(predicted_classes) == set(classes):
            print("ALL GOOD.\nOUT FOR SEGMENTATION\n")
        else:
            print("NOPE MISSING MODES.\nOUT FOR DATA CONVERSION\n")
            inter = list(set(predicted_classes).intersection(set(classes)))
            print("AVAILABLE MODES: {}".format(inter))

        print("\nPrediction:  ", predicted_classes)
        print("Paths: ", paths)
    return classes, predicted_classes, test_path, test_data_list, num_rows, test_data, paths

def extract_images(test_path, predicted_classes, paths):
    avail_0 = os.path.join(test_path, "images", "imgs " + str(predicted_classes[0]), "imgs 0")
    avail_1 = os.path.join(test_path, "images", "imgs " + str(predicted_classes[1]), "imgs 1")
    avail_2 = os.path.join(test_path, "images", "imgs " + str(predicted_classes[2]), "imgs 2")
    path_until_images = os.path.dirname(os.path.dirname(avail_0))
    
    if not os.path.exists(avail_0):
        os.makedirs(avail_0)

    if not os.path.exists(avail_1):
        os.makedirs(avail_1)

    if not os.path.exists(avail_2):
        os.makedirs(avail_2)

    nifti_0 = nib.load(paths[0]).get_fdata()                    
    nifti_1 = nib.load(paths[1]).get_fdata()                          
    nifti_2 = nib.load(paths[2]).get_fdata()                          


    for i in range(nifti_0.shape[2]):
        slice_0 = nifti_0[:, :, i]
        slice_1 = nifti_1[:, :, i]
        slice_2 = nifti_2[:, :, i]

        path_0 = f"{avail_0}/{i:03d}.png"
        path_1 = f"{avail_1}/{i:03d}.png"
        path_2 = f"{avail_2}/{i:03d}.png"

        imageio.imwrite(path_0, slice_0)
        imageio.imwrite(path_1, slice_1)
        imageio.imwrite(path_2, slice_2)        
    return path_until_images
        
def model_selector(missing, path_until_images):
    AUTOTUNE = tf.data.experimental.AUTOTUNE
    
    if missing == 'FLAIR':
        generator_g = gans_SqueezeAttention().model
        print(generator_g.summary())
        checkpoint_path = r'E:\Graduation Project\55-EP-MODELS-FLAIR-MIX\T2-FLAIR'
        ckpt = tf.train.Checkpoint(generator_g=generator_g)
        ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)
        ckpt.restore(ckpt_manager.latest_checkpoint)
        print(f'Last Check Point: {ckpt_manager.latest_checkpoint} is restored')
        
        seq_directories = os.listdir(path_until_images)

        # Find the folder that ends with "T2"
        for directory in seq_directories:
            if directory.endswith("T2"):
                desired_folder = os.path.join(path_until_images, directory)
                return desired_folder, generator_g, AUTOTUNE        
    elif missing == 'T1':
        pass
    elif missing == 'T2':
        pass
    
def load_imgs(desired_folder, AUTOTUNE):
    img_data = tf.keras.preprocessing.image_dataset_from_directory(
                          desired_folder,
                          seed=123,
                          image_size=(256, 256),
                          batch_size=1,
                          shuffle = False)
    img_data = img_data.cache().prefetch(buffer_size=AUTOTUNE)
    img_data = img_data.map(lambda x, _: (preprocess_image_train(x)))
    return img_data

def main_seq_ident(path, model_file):
    classes, predicted_classes, test_path, test_data_list, num_rows, test_data, paths = seq_identification(path, model_file)
    print(f"Classes: {classes}")
    print(f"Predicted Classes: {predicted_classes}")
    missing = set(classes) - set(predicted_classes)
    print("Missing:", list(missing))
    
    if len(missing) > 1:
        raise Exception("wth is wrong bro?!")    

    if len(missing) < 1:
        raise Exception("wtf is wrong bro?!")     
        
    path_until_images = extract_images(test_path, predicted_classes, paths)
    missing = next(iter(missing))
    desired_folder, generator_g, AUTOTUNE = model_selector(missing, path_until_images)
    img_data = load_imgs(desired_folder, AUTOTUNE)
    
    vol = []
    dep = len(glob.glob(desired_folder + '/*'))
    for image in img_data:
        img = predict_image(image, generator_g)
        vol.append(img)
    
    # Delete the images directory used for prediction and its contents
    shutil.rmtree(path_until_images)
    
    original_vol_path = sorted(glob.glob(test_path + '/*'))[1]
    original_vol = nib.load(original_vol_path)
    original_shape = original_vol.shape

    vol = np.array(vol).transpose(1, 2, 0)
    vol = ndimage.zoom(vol, (original_shape[0]/vol.shape[0],
                                               original_shape[1]/vol.shape[1],
                                               original_shape[2]/vol.shape[2]), order=0)

    v = nib.Nifti1Image(np.array(vol), original_vol.affine)            # to save this 3D (ndarry) numpy
    brats_num = int(os.path.basename(test_path)[-5:])

    if missing == 'T1':
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t1.nii.gz')

    elif missing == 'T2':
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_t2.nii.gz')

    elif missing == 'FLAIR':
        nib.save(v, test_path + '/' + f'BraTS2021_0{brats_num:04d}_flair.nii.gz')

# %%
main_seq_ident(path=r"C:\Users\DELL\Desktop\BraTS2021_00000", model_file=r"C:\Users\DELL\Graduation Project\Codes and Scripts\type-identification-mri-sequences\models\b4_sl4.pth")
# Out:
#                                                 path  label
# 0  C:\Users\DELL\Desktop\BraTS2021_00000\BraTS202...    NaN
# 1  C:\Users\DELL\Desktop\BraTS2021_00000\BraTS202...    NaN
# 2  C:\Users\DELL\Desktop\BraTS2021_00000\BraTS202...    NaN
# Starting loading data...
# Loading C:\Users\DELL\Desktop\BraTS2021_00000\BraTS2021_00000_t1.nii.gz
# Loaded 1 / 3 (counting discarded).
# Loading C:\Users\DELL\Desktop\BraTS2021_00000\BraTS2021_00000_t1ce.nii.gz
# Loaded 2 / 3 (counting discarded).
# Loading C:\Users\DELL\Desktop\BraTS2021_00000\BraTS2021_00000_t2.nii.gz
# Loaded 3 / 3 (counting discarded).
#
# Loading time: 0h0min0s
# Actually loaded: 3 ("Other" class discarded)
# Tested 1 of 3 files.
# Tested 2 of 3 files.
# Tested 3 of 3 files.
# NOPE MISSING MODES.
# OUT FOR DATA CONVERSION
#
# AVAILABLE MODES: ['T2', 'T1c', 'T1']
#
# Prediction:   ['T1', 'T1c', 'T2']
# Paths:  ['C:\\Users\\DELL\\Desktop\\BraTS2021_00000\\BraTS2021_00000_t1.nii.gz', 'C:\\Users\\DELL\\Desktop\\BraTS2021_00000\\BraTS2021_00000_t1ce.nii.gz', 'C:\\Users\\DELL\\Desktop\\BraTS2021_00000\\BraTS2021_00000_t2.nii.gz']
# Classes: ['FLAIR', 'T1', 'T1c', 'T2']
# Predicted Classes: ['T1', 'T1c', 'T2']
# Missing: ['FLAIR']
# Lossy conversion from float64 to uint8. Range [0.0, 484.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1085.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 657.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 577.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2712.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1127.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 617.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2895.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1243.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 643.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 3788.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1340.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 633.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 3336.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1223.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 670.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 3697.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1257.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 714.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 4206.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 987.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 718.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 3792.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 995.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 740.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 3375.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 929.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 841.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 4949.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1303.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 974.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 5104.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1368.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1254.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 5481.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1441.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1429.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6404.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1492.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1280.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6244.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1524.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1430.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 5963.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1458.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1513.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6488.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1523.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1732.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6403.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1278.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1450.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6140.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1386.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1171.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6202.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1458.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 895.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6646.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1376.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 794.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6382.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1518.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 809.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6675.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1573.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 805.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6645.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1583.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 801.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6668.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1578.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 811.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6391.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1659.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 901.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6756.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1706.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 848.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 6967.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1625.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 861.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7198.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1684.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 847.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7617.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1665.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 834.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7369.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1725.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 915.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7096.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1664.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 922.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7612.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1695.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 847.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7644.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1775.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 927.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 7515.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1814.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 880.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8309.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1809.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 905.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8796.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1866.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 889.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8995.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1871.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 867.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9152.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1810.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 873.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8965.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1779.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 899.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9224.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1752.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 962.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9252.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1691.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 952.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9137.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1997.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1514.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9174.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1752.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1456.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9157.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1945.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1397.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9378.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1896.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1274.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9304.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1907.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1072.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9775.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1862.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1100.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10065.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2098.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1149.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10111.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1985.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1197.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10148.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1961.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1245.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10638.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1972.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1169.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11022.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2078.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1105.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11061.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2051.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1084.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10972.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2114.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1073.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10918.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2150.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1116.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11268.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2194.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1074.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11556.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2110.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1071.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11657.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2116.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1077.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11719.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2162.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1140.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11787.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2153.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1300.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11835.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2139.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1265.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11948.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2314.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1338.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11969.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2283.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1411.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11985.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2238.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1485.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11994.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2208.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1558.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11890.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2271.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1562.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11974.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2216.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1465.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12122.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2197.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1547.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12338.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2421.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1718.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12170.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2215.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1951.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12165.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2252.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1829.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12092.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2279.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1808.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11786.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2283.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1788.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11768.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2296.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1726.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11982.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2281.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1746.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12136.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2299.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1718.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12298.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2259.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1689.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12021.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2338.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1700.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12014.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2266.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1663.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11508.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2339.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1679.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11592.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2238.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1475.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11444.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2228.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1412.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11557.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2334.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1378.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11676.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2220.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1505.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11759.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2246.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1448.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11610.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2317.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1505.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11007.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2396.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1513.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11165.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2231.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1588.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11298.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2228.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1618.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11194.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2219.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1626.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10985.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2260.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1552.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10927.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2304.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1482.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10828.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1666.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10987.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2185.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1650.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11154.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2167.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1517.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11352.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2142.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1490.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11615.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2213.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1525.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11441.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2264.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1617.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11283.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2265.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1761.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11198.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2190.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1576.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11365.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2218.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1608.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12068.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2084.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1541.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11990.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2153.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1556.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11303.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2145.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1629.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10394.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2139.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1668.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11307.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2208.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1572.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12343.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2191.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1584.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12297.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2117.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1848.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 12134.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2182.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1829.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11616.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2089.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1691.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10992.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2169.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1660.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11057.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2120.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1536.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11108.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2084.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1595.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10805.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2069.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1798.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10996.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2053.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1707.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11149.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2045.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1559.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11835.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2004.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1654.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11547.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2050.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1822.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11689.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2092.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2023.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11657.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2044.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1653.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 11189.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2106.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1483.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10533.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1965.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1376.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10958.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1985.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1546.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 10904.0]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-46.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-47.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-48.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-48.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-50.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-50.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-52.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-53.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-54.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'm' for (root).generator_g.layer_with_weights-54.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-7.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-7.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-9.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-9.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-11.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-13.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-13.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-15.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-15.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-16.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-17.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-18.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-18.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-19.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-19.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-20.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-20.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-21.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-21.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-22.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-23.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-24.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-24.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-25.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-25.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-26.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-26.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-27.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-27.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-28.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-29.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-30.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-30.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-31.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-31.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-32.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-32.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-34.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-35.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-36.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-36.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-38.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-38.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-40.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-41.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-42.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-42.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-43.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-43.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-44.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-44.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-45.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-46.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-47.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-48.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-48.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-50.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-50.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-52.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-53.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-54.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).generator_g_optimizer's state 'v' for (root).generator_g.layer_with_weights-54.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Found 146 files belonging to 1 classes.
